# %%
import pandas as pd
import numpy as np

#df = pd.read_csv("../maga/src/test/resources/iris.data")
#df = df.sample(frac=1).reset_index(drop=True)
#df.to_csv("../maga/src/test/resources/iris_shuffle.data", index=False)
df = pd.read_csv("../maga/src/test/resources/iris_shuffle.data")
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth          species
# 0            5.7         2.5          5.0         2.0   Iris-virginica
# 1            5.7         4.4          1.5         0.4      Iris-setosa
# 2            5.7         3.8          1.7         0.3      Iris-setosa
# 3            6.0         2.2          4.0         1.0  Iris-versicolor
# 4            7.6         3.0          6.6         2.1   Iris-virginica
# ..           ...         ...          ...         ...              ...
# 145          6.8         3.2          5.9         2.3   Iris-virginica
# 146          6.3         2.9          5.6         1.8   Iris-virginica
# 147          6.2         2.9          4.3         1.3  Iris-versicolor
# 148          4.9         3.0          1.4         0.2      Iris-setosa
# 149          5.3         3.7          1.5         0.2      Iris-setosa
#
# [150 rows x 5 columns]

# %% [markdown]
# #### 1. Get average sepal width

# %%
df['sepalWidth'].mean()
# Out:
# 3.054

# %% [markdown]
# #### 2. Get average petal square - petal width multiplied on petal length

# %%
def petalSquare(df):
    return df['petalWidth'] * df['petalLength']

def averagePetalSquare(df):
    return petalSquare(df).mean()

averagePetalSquare(df)
# Out:
# 5.793133333333332

# %% [markdown]
# #### 3. Get average petal square for flowers with sepal width > 4

# %%
averagePetalSquare(df[df['sepalWidth'] > 4])
# Out:
# 0.3433333333333333

# %% [markdown]
# #### 4. Get flowers grouped by Petal size (Petal.SMALL, etc.)

# %%
df['petalSquare'] = petalSquare(df)
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth          species  \
# 0            5.7         2.5          5.0         2.0   Iris-virginica
# 1            5.7         4.4          1.5         0.4      Iris-setosa
# 2            5.7         3.8          1.7         0.3      Iris-setosa
# 3            6.0         2.2          4.0         1.0  Iris-versicolor
# 4            7.6         3.0          6.6         2.1   Iris-virginica
# ..           ...         ...          ...         ...              ...
# 145          6.8         3.2          5.9         2.3   Iris-virginica
# 146          6.3         2.9          5.6         1.8   Iris-virginica
# 147          6.2         2.9          4.3         1.3  Iris-versicolor
# 148          4.9         3.0          1.4         0.2      Iris-setosa
# 149          5.3         3.7          1.5         0.2      Iris-setosa
#
#      petalSquare
# 0          10.00
# 1           0.60
# 2           0.51
# 3           4.00
# 4          13.86
# ...

# %%
def classifyByPetal(x):
    if x < 2.0:
        return 'small'
    elif x < 5.0:
        return 'medium'
    return 'large'

df['class'] = df['petalSquare'].apply(classifyByPetal)
df
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth          species  \
# 0            5.7         2.5          5.0         2.0   Iris-virginica
# 1            5.7         4.4          1.5         0.4      Iris-setosa
# 2            5.7         3.8          1.7         0.3      Iris-setosa
# 3            6.0         2.2          4.0         1.0  Iris-versicolor
# 4            7.6         3.0          6.6         2.1   Iris-virginica
# ..           ...         ...          ...         ...              ...
# 145          6.8         3.2          5.9         2.3   Iris-virginica
# 146          6.3         2.9          5.6         1.8   Iris-virginica
# 147          6.2         2.9          4.3         1.3  Iris-versicolor
# 148          4.9         3.0          1.4         0.2      Iris-setosa
# 149          5.3         3.7          1.5         0.2      Iris-setosa
#
#      petalSquare   class
# 0          10.00   large
# 1           0.60   small
# 2           0.51   small
# ...

# %%
grouped = df.groupby('class')

# %%
small = grouped.get_group('small')
print(small.shape[0])
small
# Out:
# 50
#      sepalLength  sepalWidth  petalLength  petalWidth      species  \
# 1            5.7         4.4          1.5         0.4  Iris-setosa
# 2            5.7         3.8          1.7         0.3  Iris-setosa
# 7            4.8         3.1          1.6         0.2  Iris-setosa
# 10           5.4         3.4          1.7         0.2  Iris-setosa
# 13           5.2         3.4          1.4         0.2  Iris-setosa
# 23           5.4         3.9          1.3         0.4  Iris-setosa
# 27           5.4         3.4          1.5         0.4  Iris-setosa
# 30           4.4         3.2          1.3         0.2  Iris-setosa
# 34           4.8         3.4          1.9         0.2  Iris-setosa
# 35           5.1         3.8          1.6         0.2  Iris-setosa
# 37           4.9         3.1          1.5         0.1  Iris-setosa
# 39           5.5         3.5          1.3         0.2  Iris-setosa
# 41           5.0         3.3          1.4         0.2  Iris-setosa
# ...

# %%
medium = grouped.get_group('medium')
print(medium.shape[0])
medium
# Out:
# 13
#      sepalLength  sepalWidth  petalLength  petalWidth          species  \
# 3            6.0         2.2          4.0         1.0  Iris-versicolor
# 19           5.0         2.3          3.3         1.0  Iris-versicolor
# 38           5.5         2.4          3.7         1.0  Iris-versicolor
# 46           5.7         2.6          3.5         1.0  Iris-versicolor
# 47           5.8         2.6          4.0         1.2  Iris-versicolor
# 65           4.9         2.4          3.3         1.0  Iris-versicolor
# 71           5.5         2.4          3.8         1.1  Iris-versicolor
# 82           5.1         2.5          3.0         1.1  Iris-versicolor
# 86           5.6         2.5          3.9         1.1  Iris-versicolor
# 101          5.8         2.7          4.1         1.0  Iris-versicolor
# 116          5.6         2.9          3.6         1.3  Iris-versicolor
# 137          5.8         2.7          3.9         1.2  Iris-versicolor
# ...

# %%
large = grouped.get_group('large')
print(large.shape[0])
large
# Out:
# 87
#      sepalLength  sepalWidth  petalLength  petalWidth          species  \
# 0            5.7         2.5          5.0         2.0   Iris-virginica
# 4            7.6         3.0          6.6         2.1   Iris-virginica
# 5            7.7         2.8          6.7         2.0   Iris-virginica
# 6            6.3         2.3          4.4         1.3  Iris-versicolor
# 8            6.7         3.3          5.7         2.5   Iris-virginica
# ..           ...         ...          ...         ...              ...
# 143          5.7         3.0          4.2         1.2  Iris-versicolor
# 144          6.4         3.2          5.3         2.3   Iris-virginica
# 145          6.8         3.2          5.9         2.3   Iris-virginica
# 146          6.3         2.9          5.6         1.8   Iris-virginica
# 147          6.2         2.9          4.3         1.3  Iris-versicolor
#
#      petalSquare  class
# 0          10.00  large
# 4          13.86  large
# 5          13.40  large
# ...

# %% [markdown]
# #### Get max sepal width for flowers grouped by species

# %%
df.groupby('species').agg({'sepalWidth': np.max})
# Out:
#                  sepalWidth
# species
# Iris-setosa             4.4
# Iris-versicolor         3.4
# Iris-virginica          3.8
